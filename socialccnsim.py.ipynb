# %% [markdown]
# ## 0 Import all neccesary packages

# %%
#Within AS
# Caching Rate
import random
from multiprocessing import Queue
import sys
import sqlite3

import re
import optparse
import logging
import numpy
import logging
from visualize import visualizer as vis


import threading
from user import User

import sched, time
from topology_manager import TopologyManager, Paths, SocialPaths
import tempfile

import matplotlib.pyplot as plt
import networkx as nx

from zipf import gen_biased_zipf_requests, gen_zipf_requests
from Autonomous_System import AS

# %%
def zipf_generator(num_of_content = 100, num_of_request = 1000, offset = 0):
    alpha = 1
    req, pattern = gen_biased_zipf_requests(alpha = 1,number_of_content = num_of_content, number_of_request = num_of_request, offset = offset)
    return pattern

# %%
pattern = zipf_generator(num_of_content = 100, num_of_request = 1000, offset = 0)
plt.plot(pattern.keys(), pattern.values())
plt.title('request pattern')
plt.show()

# %% [markdown]
# ## 1 Prepare instruaction parser

# %%
parser = optparse.OptionParser()
parser.add_option("-c", "--cache-size-per-node",
              dest="cache_size_per_node",
              help="space of cache allocated for every node in the topology",
              type=int,
              )
parser.add_option("-s", "--strategy",
              dest="caching_strategy",
              help="caching Strategy used for evaluating the trace"
              )
parser.add_option("-u", "--social-connections",
              dest="social_graph",
              help='social connections between users of the trace. Every trace includes users that executes actions.'
)
parser.add_option("-t", "--topology",
              dest="network_topology",
              help='network topology used for executing the trace.'
)
parser.add_option("-f", "--trace-file",
              dest="trace",
              default="",
              help='the trace to be executed',
)
parser.add_option("-p", "--replacement-policy",
              dest="replacement_policy",
              help='replacement policy used at every network node.',
)
parser.add_option("-m", "--mobility-enabled",
              dest="mobility_enabled",
              default=False,
              action="store_true",
              help="Enable mobility of users"
)
parser.add_option("-d", "--debug",
              dest="debug",
              default=False,
              action="store_true",
              help="Enable debugging options"
)
parser.add_option("-r", "--step-printing",
              dest="step_printing",
              default="",
              help = ""
)
parser.add_option("-z", "--zipf",
              dest="zipf",
              default=False,
              action="store_true",
              help = ""
)
parser.add_option("-e", "--method",
                 dest = "method",
                 default='random',
                 help = "random/geographical/onepublisher"
)
parser.add_option("-g", "--single-user",
                 dest = "single",
                 default=False,
                 action="store_true",
                 help = "if set, each topology node comes with only one user"
)
parser.add_option("-v", "--verbose",
                 dest = "verbose",
                 default=False,
                 action="store_true",
                 help = "if set, print cache storage info"
)
# Out:
# <Option at 0x13cbb2280: -v/--verbose>

# %%
def setup_logger(logger_name, log_file, level=logging.INFO, format_style = '%(asctime)-15s %(message)s',verbose=True):
    l = logging.getLogger(logger_name)
    formatter = logging.Formatter(format_style)
    fileHandler = logging.FileHandler(log_file, mode='w')
    fileHandler.setFormatter(formatter)
    l.addHandler(fileHandler)
    streamHandler = logging.StreamHandler()
    streamHandler.setFormatter(formatter)
    l.addHandler(streamHandler)
    l.setLevel(level)
    return l

# %%
class Executor(object):
    def __init__(self, logger, social_graph, topology, cache_size, caching_strategy, cache_policy, sequence_filename = '', mobility_enabled = False, step_printing = [], topology_file = None, zipf = False, method = 'random', single = False, verbose = False):
        self.lock = threading.Lock()
        self.condition = threading.Condition()
        #########################################
        #Initialize AS
        ##########################################
        nodes = list(topology.nodes())
        try:
            nodes.remove("server")
        except:
            pass
        self.AS = AS(nodes, True)
        logger.info("initialized Autonomous System")
        #########################################
        # Configuration
        #########################################
        self.round = 0
        self.num_of_request = 1000
        self.initialized_server = False
        self.num_of_content = 1000
        self.contents = ["/content/%s"%str(i) for i in range(self.num_of_content)]
        #########################################
        self.conf = {}
        self.conf['caching_strategy'] = caching_strategy
        self.conf['cache_policy'] = cache_policy
        self.conf['sequence_from_file'] = sequence_filename != ''
        self.conf['step_printing'] = step_printing
        self.method = method
        self.zipf_para = 1
        if self.conf['step_printing'] != None:
            self.steps = 0
        else:
            self.steps = None
        self.verbose = verbose
        #print("singledemo",single)
        #print("zipfdemo",zipf)

        ##########################################3
        # The topology manager handles user connection to CCN nodes.
        self.request_nodes = list(topology)
        self.topology = topology
        self.add_server_node()
        if single:
            self.social_nodes = self.topology
        ##############################################
        # Debugging
        #print(self.topology.nodes())
        logger.debug('Topology manager, connect users started')
        topology_coords = nx.spring_layout(topology)
        #topology_coords = {}
        #for node in topology.nodes():
        #    topology_coords[node] = (
        #            random.randint(0, 100),
        #            random.randint(0, 100)
        #    )
        self.topology_coords = topology_coords
        if single:
            self.social_graph = self.topology
            self.topology_nodes = TopologyManager(self.topology, self.topology, topology_coords, mobility_enabled, topology_file = topology_file)
        else:
            self.topology_nodes = TopologyManager(self.topology, self.social_graph, topology_coords, mobility_enabled, topology_file = topology_file)
        # 社交用户与节点之间关系为随机指定型
        # 后续的请求是用户发出的，所以，主要是要看如何将用户与请求 Pattern之间建立起关系
        self.topology_nodes.set_method(self.method)
        # 从网络中随机初始化网络节点
        # 从Social Network中随机初始化社交节点位置
        if not single:
            for user in social_graph.nodes():
                # update user node(user,pos)
                # initiate user position(coords_user)
                # 将用户映射到最近的拓扑节点上
                self.topology_nodes.update_user_position(user,(random.randint(0, 100), random.randint(0, 100)))
            self.topology_nodes.update_all_users_position()
        else:
            # 在单用户场景中，我们需要将用户初始化于相应的节点中
            for node in topology.nodes():
                    #TODO
                    self.topology_nodes.update_user_node(node,node)
        logger.debug('Topology manager, connect users finished')

        #
        self.users = {}
        for user in self.social_graph.nodes():
            self.users[user] = User(user)

        logger.debug('Start simulation')
        # debugging
        #print(self.topology_nodes.paths._path)

        self.sched = sched.scheduler(time.time, time.sleep)

        # Generate Sequence
        #print "generate sequence"
        if sequence_filename == '':
            self.generate_sequence()
        else:
            self.initialize_scheduler_from_file(sequence_filename)

        # Initialize Caches
        self.lock.acquire()
        # !!Cache Strategy Upper
        caching_strategy_upper = self.conf['caching_strategy'].upper()
        cm = getattr(getattr(__import__('cache_management.%s'%caching_strategy_upper), caching_strategy_upper), caching_strategy_upper)
        self.caches = cm(
                self.conf['cache_policy'],
                cache_size,
                self.social_graph,
                self.topology,
                self.topology_nodes,
                threshold = None
        )
        logger.debug('Loaded caching strategy')
        self.lock.release()
        self.initialize_catalog()
        ##//Initiate

    
    def initialize_scheduler(self):
        self.sched = sched.scheduler(time.time, time.sleep)
        ########################
        # TODO 接上Server
        if not self.initialized_server:
            self.initialize_Server()
            self.initialized_server = True
        ##########################
        #self.extract_sequence()
        #########################
        # Pending
        # 插入ZipF请求
        print("Start Simulating!")
        self.gen_zipf_sequence(num_of_content = self.num_of_content, num_of_request = self.num_of_request, r = self.round)
        ######################

        assert not self.sched.empty()


    ##############################################
    #TODO: currently not being used
    def initialize_scheduler_from_file(self, filename):
        self.seq_file = open(filename, 'r')
        self.seq_n = 0
    
    def extract_sequence(self):
        line = self.seq_file.readline()
        while line != '': #Empty line, we reach the end of the sequence
            # Retrieve fields in a line
            # Line format
            # |timestamp | event | User | mobility_x | mobility_y
            result = re.match ("(?P<timestamp>[0-9]*\.[0-9]+)\t(?P<activity>Retrieve|Publish|retrieve|publish|Retrievecontent|Publishcontent)\t(?P<user>[0-9]+)\t\((?P<dependent>.*)\)\t\((?P<mobility_x>[0-9\.]*), ?(?P<mobility_y>[0-9\.]*)\)", line)
            if result != None:
                #print step result
                if self.steps != None and self.steps < len(self.conf['step_printing']) and float(result.group('timestamp')) > self.conf['step_printing'][self.steps]:
                    # debugging
                    print(self.steps)
                    self.sched.enter(self.seq_n * 0.01, 0, self.printStepSummary, (self.conf['step_printing'][self.steps],))
                    self.steps += 1
                # schedule an event (delay, priority, action, argument=())
                # delay, priority, action, argument=()
                # 使用的工具为：
                # 1 Producer2
                # 2 consumer
                # 3 consume_from_server
                pos = (float(result.group('mobility_x')), float(result.group('mobility_y')))
                if result.group('activity').lower() in ['publishcontent', 'publish']:
                    self.sched.enter(self.seq_n * 0.01, 0, self.producer2, (int(result.group('user')), pos, "/content/%s"%result.group('dependent').split(',')[0] ))
                # 两类consumer
                elif result.group(2).lower() == 'retrieve':
                    self.sched.enter(self.seq_n * 0.01, 0, self.consumer, (int(result.group('user')), pos,))
                elif result.group(2).lower() == 'retrievecontent':
                    #print(self.seq_n * 0.01, 0,self.consume_from_server, (int(result.group('user'))), pos, "/content/%s"%result.group('dependent').split(',')[0])
                    self.sched.enter(self.seq_n * 0.01, 0, self.consume_from_server, (int(result.group('user')), pos, "/content/%s"%result.group('dependent').split(',')[0]))
            else:
                print("repr line: %s"%repr(line))
                exit(-1)
            self.seq_n+=1
            line=self.seq_file.readline()
    def initialize_catalog(self):
        self.f = tempfile.NamedTemporaryFile(delete=True, dir='/tmp/')
        self.conn = sqlite3.connect(self.f.name)
        self.c = self.conn.cursor()

        #c.execute('''DROP table catalog''')
        self.c.execute('''CREATE TABLE catalog
                     (content_name text, publisher int, date double, refer text, refered_level int, topic int)''')

    def generate_sequence(self, sequence = []):
        assert type(sequence) == list
        if sequence == []:
            self.sequence = [random.randint(0, len(self.social_graph.nodes())-1) \
                for i in range(0, len(self.social_graph)*40)]
            random.shuffle(self.sequence)
        else:
            self.sequence = sequence

    ###################################
    # 加入Server节点
    def add_server_node(self):
        node = random.choice(list(self.topology.nodes()))
        self.topology.add_node("server")
        self.topology.add_edge(node,"server")
        self.server = "server"
    ############################################
    # Initialize Server
    # 随机选取一个节点
    # 作为Server接上内容
    def initialize_Server(self):
        #################################
        # TODO
        # 找到中心节点
        # 加入一个Server节点
        # Pending
        for content in self.contents:
            self.sched.enter(self.seq_n * 0.01, 0, self.producer3, (self.server, content))
        #################################

    #################################
    # 生成符合Zipf分布的请求，并插入仿真器中
    # TODO:a Zipf sequence generator
    # Pending 01 将请求插入进编辑器中
    #def generate_Zipf_sequence(self,sequence = []):
    def zipf_generator(self,num_of_content, num_of_request, offset):
        alpha = self.zipf_para
        req, _ = gen_biased_zipf_requests(alpha = alpha,number_of_content = num_of_content, number_of_request = num_of_request, offset = offset)
        return req
        
    def gen_zipf_sequence(self, num_of_content = 1000, num_of_request = 10000, r = 0, offset = 0):
        sequence = self.zipf_generator(num_of_content, 10*num_of_content, offset)
        requests = sequence[r*num_of_request:((r+1)*num_of_request)]
        #consume_from_server(user,position, contentname)
        # nodes must convert to list, or error appears
        for request in requests:
            ##############################################
            if self.steps != None and self.steps < len(self.conf['step_printing']) and float(result.group('timestamp')) > self.conf['step_printing'][self.steps]:
                    self.sched.enter(self.seq_n * 0.01, 0, self.printStepSummary, (self.conf['step_printing'][self.steps],))
                    self.steps += 1
            ##############################################
            request_node = random.choice(self.request_nodes)
            while(request_node == "server"):
                request_node = random.choice(self.request_nodes)
            #consume_from_server(user,position, contentname)
            #目标是先从目标节点进行查找
            ## Scheduler 的用法
            # scheduler.enter(delay, priority, action, argument=(), kwargs={})
            # Pending# consume from server 应该被改成从目标中获取
            #print(self.social_graph.nodes())
            #pos = self.topology_coords[request_node]
            #self.sched.enter(self.seq_n * 0.01, 0, self.consume_from_server, (int(result.group('user')), pos, "/content/%s"%result.group('dependent').split(',')[0]))
            req = self.contents[request]
            # print(request_node, type(pos), type(req))
            # print(self.seq_n * 0.01, 0, self.consume_from_server, request_node, pos, req)
            self.sched.enter(self.seq_n * 0.01, 0, self.consume_from_target, (request_node, req))
            self.seq_n+=1
        print("total seq num: ",self.seq_n)
     #################################
    
    def run(self):
        #print "the process begins"
        self.initialize_scheduler()
        self.sched.run()
        self.round += 1
        time.sleep(2)

        
    def __del__(self):
        self.conn.close()
    # 使用的是这一个！！
    # 将文件插入到数据库中
    def producer3(self, social_publisher, content, reference = '', topic = 0):
        #self.topology_nodes.update_user_position(social_publisher, position)
        self.caches.incr_publish()
        #content_name = "/friend%i/%i"%(social_publisher, self.stats.increase_messages())
        #print("node",social_publisher, "publish",content)
        content_name = "%s"%content
        _new_content_name = content_name
        if reference == '':
            _ref_level = 0
        else:
            #Select 
            _ref_level = 0
            for row in self.c.execute('SELECT * FROM catalog WHERE content_name=\"%s\" LIMIT 1'%reference):
                _ref_level = row[4]+1
                _new_content_name = row[0]
                topic = row[5]
            assert _ref_level == 1, _ref_level
        self.c.execute("INSERT INTO catalog VALUES (\"%s\",'%s', '%s', '%s', %d, %d);"%(content_name, social_publisher, time.time(), reference, _ref_level, topic))
        self.lock.acquire()
        self.caches.post_production(_new_content_name, social_publisher)
        self.lock.release()
    # 使用的是这一个！！
    # 将文件插入到数据库中
    def producer2(self, social_publisher, position, content, reference = '', topic = 0):
        self.topology_nodes.update_user_position(social_publisher, position)
        self.caches.incr_publish()
        #content_name = "/friend%i/%i"%(social_publisher, self.stats.increase_messages())
        #print("node",social_publisher, "publish",content)
        content_name = "%s"%content
        _new_content_name = content_name
        if reference == '':
            _ref_level = 0
        else:
            #Select 
            _ref_level = 0
            for row in self.c.execute('SELECT * FROM catalog WHERE content_name=\"%s\" LIMIT 1'%reference):
                _ref_level = row[4]+1
                _new_content_name = row[0]
                topic = row[5]
            assert _ref_level == 1, _ref_level
        self.c.execute("INSERT INTO catalog VALUES (\"%s\",'%s', '%s', '%s', %d, %d);"%(content_name, social_publisher, time.time(), reference, _ref_level, topic))
        self.lock.acquire()
        self.caches.post_production(_new_content_name, social_publisher)
        self.lock.release()
    ## Producer with position This is already abandoned~
    def producer(self, social_publisher, position, reference = '', topic = 0):
        logger.error("WARNING, this function is deprecated")
        exit(-1)
        self.topology_nodes.update_user_position(social_publisher, position)
        self.caches.incr_publish()
        content_name = "/friend%i/%i"%(social_publisher, self.stats.increase_messages())
        _new_content_name = content_name
        if reference == '':
            _ref_level = 0
            topic = self.users[social_publisher].decide_next_topic()
        else:
            #Select 
            _ref_level = 0
            for row in self.c.execute('SELECT * FROM catalog WHERE content_name=\"%s\" LIMIT 1'%reference):
                _ref_level = row[4]+1
                _new_content_name = row[0]
                topic = row[5]
            assert _ref_level == 1, _ref_level
        self.c.execute("INSERT INTO catalog VALUES (\"%s\",'%s', '%s', '%s', %d, %d);"%(content_name, social_publisher, time.time(), reference, _ref_level, topic))
        self.lock.acquire()
        self.caches.post_production(_new_content_name, social_publisher)
        self.lock.release()
    #consume_from_server(user,position, contentname)
    def consume_from_server(self, social_issuer, position, content_name):
        #print "consume_from_server %s"%content_name
        # 首先将用户的位置进行更新为新的地点
        self.topology_nodes.update_user_position(social_issuer, position)
        # 然后
        content_retrieved = {}
        last = 0
        #寻找到存储这个内容的节点
        # Print Flag
        #print("Consume: ",content_name)
        for row in self.c.execute('SELECT * FROM catalog WHERE content_name == \"%s\" LIMIT 1'%( content_name )):
            # row的格式是：
            # content_name text, publisher int, date double, refer text, refered_level int, topic int
            last = row[0]
            reference = row[3]
            referer_level = row[4]
            topic = row[5]
            interest = last
            #从拓扑图中获取路径
            # 由于获取的时候
            # Print Flag
            
            path = self.topology_nodes.get_path(social_issuer, row[1])
            # Retrieve content and calculate statistics
            self.lock.acquire()
            self.caches._retrieve_from_caches(interest, path)
            self.lock.release()
        if self.verbose:
            print(self.printStats())

    def consumer(self, social_issuer, position):
        self.topology_nodes.update_user_position(social_issuer, position)
        content_retrieved = {}
        for social_neighbour in self.social_graph.neighbors(social_issuer):
            topology_neighbour = self.topology_nodes[social_neighbour]
            last = 0
            
            for row in self.c.execute('SELECT * FROM catalog WHERE publisher=%s and date BETWEEN %2f AND %2f ORDER BY date DESC LIMIT 1'%(social_neighbour, time.time()-0.2, time.time())):
                last = row[0]
                reference = row[3]
                referer_level = row[4]
                topic = row[5]
                #detecting original consumer
                while referer_level > 0:
                    for row in self.c.execute('SELECT * FROM catalog WHERE content_name=\"%s\" ORDER BY date DESC LIMIT 1'%reference):
                        last = row[0]
                        reference = row[3]
                        referer_level = row[4]
                        topic = row[5]
                #print row
                interest = last
                path = self.topology_nodes.get_path(social_issuer, social_neighbour)
                self.lock.acquire()
                self.caches._retrieve_from_caches(interest, path)
                self.lock.release()
            if self.verbose:
                print(self.printStats())
#########################################################
    # TODO: 先从目标节点中尝试获取缓存信息，然后再尝试从Server处获取缓存信息
    # Pending 02
    def consume_from_target(self, consumer, content_name) :
        # 目标节点
        # Pending： 需要向目标节点发出请求
        # target = hash_target(content_name)
        content_retrieved = False
        target = self.AS.get_node(content_name)
        #print("Consume: ",content_name,"Target is: ", target)
        path_to_target = self.topology_nodes.get_path(consumer, target)
        path_to_server = self.topology_nodes.get_path(consumer, self.server)
        target_to_server = self.topology_nodes.get_path(target,self.server)
        self.lock.acquire()
        self.caches.retrieve_content(content_name, target, path_to_target,self.server, target_to_server)
        #try:
            #  从目标节点中进行获取内容
            # retrieve_content(self, interest, target, path_to_target, server, path_to_server):
        #    self.caches.retrieve_content(content_name, target, path_to_target,self.server, target_to_server)
        #except:
        #    self.caches._retrieve_from_caches(content_name, path_to_server)
        self.lock.release()
        #if self.verbose:
        #    print(self.printStats())
#########################################################
    def get_expired_elements(self):
        # get last element of each social user
        #TODO: refactoring URGENT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        return 0
    def get_diversity(self):
        return self.stats.get_diversity(self.caches)
    def printStats(self):
        return self.caches.stats_summary()
    #############################################
    # print cache detail
    def printCaches(self):
        return self.caches.print_caches()
    ##############################################
    def printStepSummary(self, timestamp):
        print("=> {0} {1}".format(timestamp, self.caches.stats_summary()))
    def finishSimulation(self):
        del self.caches
        del self.topology_nodes 
        del self.sched
        self.c.close()
        self.lock.acquire()
        self.lock.release()
        self.condition.acquire()
        self.condition.notify()
        self.condition.release()

# %%
def mainFunc(options):
    #logger = setup_logger('logger', 'example.log', level=logging.INFO)
    if options.debug:
        root = logging.getLogger()
        root.setLevel(logging.DEBUG)
        ch = logging.StreamHandler(sys.stdout)
        ch.setLevel(logging.DEBUG)
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        ch.setFormatter(formatter)
        root.addHandler(ch)
        root.info('Enable Debugging')
        # delivering original parameters
    CACHE_SIZE = options.cache_size_per_node
    CACHING_STRATEGY = options.caching_strategy
    RUNS = 2
    SOCIAL_GRAPH = options.social_graph
    TOPOLOGY_GRAPH = options.network_topology
    CACHE_STRUCTURE = options.replacement_policy
    SEQUENCE_FILE = options.trace
    ZIPF = options.zipf
    SINGLE = options.single
    VERBOSE = options.verbose
    if SEQUENCE_FILE == "":
        logging.error("no trace file, using random generation of messages.")
        exit()
    METHOD = options.method
    if METHOD not in ['random','geographical','onepublisher']:
        root.error("WARNING, method is not listed, set to random")
        METHOD = 'random'
    MOBILITY_ENABLED = options.mobility_enabled
    if MOBILITY_ENABLED:
        root.debug("Mobility enabled")
    else:
        root.debug("Mobility disabled")
    
    try:
        STEP_PRINTING = [float(x) for x in options.step_printing.split(",") if x != '']
        root.debug("Step printing activated")
    except IndexError:
        STEP_PRINTING = []
        root.debug("Step printing not activated")
    CACHE_STRUCTURE = re.match('([a-zA-Z0-9_]*(\((?P<params>([0-9]*\.?[0-9]*,? ?)*)\))?)', CACHE_STRUCTURE)
    assert CACHE_STRUCTURE != None
    CACHE_STRUCTURE = CACHE_STRUCTURE.group(1)
    # Import Social Graph
    # Social Graph from folder graphs
    G = getattr(__import__('graphs.%s'%SOCIAL_GRAPH), SOCIAL_GRAPH).G
    #plotGraph(G)
    root.debug('Social Graph loaded')
    #random.seed(10442)
    for iteration in range(0, RUNS):
        # Import Topology Graph as a new class(peterson and pharse as topology class)
        # social_graph is imported as a new class from folder graph, in this case, alibama
        petersen = getattr(__import__('graphs.%s'%TOPOLOGY_GRAPH), TOPOLOGY_GRAPH).G
        #plotGraph(petersen)
        # social_graph, topology, cache_size, caching_strategy, cache_policy, sequence_filename, mobility_enabled, step_printing, topology_file
        executor = Executor(logger,G, petersen, CACHE_SIZE, CACHING_STRATEGY, CACHE_STRUCTURE, SEQUENCE_FILE, MOBILITY_ENABLED, STEP_PRINTING, topology_file=TOPOLOGY_GRAPH, zipf = ZIPF, method = METHOD, single = SINGLE, verbose = VERBOSE) 
        executor.run()
        print(executor.printStats())
        executor.finishSimulation()
        root.handlers.pop()
        logger = logging.getLogger('logger')
        while logger.handlers:
            logger.handlers.pop()
        cache_info = logging.getLogger('cache_info')
        while cache_info.handlers:
            cache_info.handlers.pop()
            cache_info = logging.getLogger('cache_info')

# %% [markdown]
# # Clear logger block

# %%
logger = logging.getLogger('logger')
while logger.handlers:
    logger.handlers.pop()
cache_info = logging.getLogger('cache_info')
while cache_info.handlers:
    cache_info.handlers.pop()
    cache_info = logging.getLogger('cache_info')

# %%
from importlib import reload
logging.shutdown()
reload(logging)
# Out:
# <module 'logging' from '/Users/sijiazhang/miniforge3/envs/ccnsim/lib/python3.8/logging/__init__.py'>

# %% [markdown]
# ## 4 😯Configure and run

# %%
logger = setup_logger('logger','example.log', level = logging.INFO, format_style = '%(message)s',verbose = False)
cache_info = setup_logger('cache_info','cache_info.log', level = logging.CRITICAL, format_style = '%(message)s',verbose = False)

# %%
args = '-c 10 -s pop -u facebook -t geant -p lru -f exampletrace/verysmall -d True -z True -e geographical -g True -v True'
(options,args) = parser.parse_args(args.split(' '))

# %%
#logger = setup_logger('logger', 'example.log', level=logging.INFO)
if options.debug:
    root = logging.getLogger()
    root.setLevel(logging.DEBUG)
    ch = logging.StreamHandler(sys.stdout)
    ch.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    ch.setFormatter(formatter)
    root.addHandler(ch)
    root.info('Enable Debugging')
    # delivering original parameters
CACHE_SIZE = options.cache_size_per_node
CACHING_STRATEGY = options.caching_strategy
RUNS = 5
SOCIAL_GRAPH = options.social_graph
TOPOLOGY_GRAPH = options.network_topology
CACHE_STRUCTURE = options.replacement_policy
SEQUENCE_FILE = options.trace
ZIPF = options.zipf
SINGLE = options.single
VERBOSE = options.verbose
if SEQUENCE_FILE == "":
    logging.error("no trace file, using random generation of messages.")
    exit()
METHOD = options.method
if METHOD not in ['random','geographical','onepublisher']:
    root.error("WARNING, method is not listed, set to random")
    METHOD = 'random'
MOBILITY_ENABLED = options.mobility_enabled
if MOBILITY_ENABLED:
    root.debug("Mobility enabled")
else:
    root.debug("Mobility disabled")

try:
    STEP_PRINTING = [float(x) for x in options.step_printing.split(",") if x != '']
    root.debug("Step printing activated")
except IndexError:
    STEP_PRINTING = []
    root.debug("Step printing not activated")
CACHE_STRUCTURE = re.match('([a-zA-Z0-9_]*(\((?P<params>([0-9]*\.?[0-9]*,? ?)*)\))?)', CACHE_STRUCTURE)
assert CACHE_STRUCTURE != None
CACHE_STRUCTURE = CACHE_STRUCTURE.group(1)
# Import Social Graph
# Social Graph from folder graphs
G = getattr(__import__('graphs.%s'%SOCIAL_GRAPH), SOCIAL_GRAPH).G
#plotGraph(G)
root.debug('Social Graph loaded')
#random.seed(10442)
# Import Topology Graph as a new class(peterson and pharse as topology class)
# social_graph is imported as a new class from folder graph, in this case, alibama
petersen = getattr(__import__('graphs.%s'%TOPOLOGY_GRAPH), TOPOLOGY_GRAPH).G
#plotGraph(petersen)
# social_graph, topology, cache_size, caching_strategy, cache_policy, sequence_filename, mobility_enabled, step_printing, topology_file
executor = Executor(logger,G, petersen, CACHE_SIZE, CACHING_STRATEGY, CACHE_STRUCTURE, SEQUENCE_FILE, MOBILITY_ENABLED, STEP_PRINTING, topology_file=TOPOLOGY_GRAPH, zipf = ZIPF, method = METHOD, single = SINGLE, verbose = VERBOSE) 
for iteration in range(0, RUNS):
    #print(executor.caches.print_caches())
    executor.run()    
    print(executor.printStats())
    #print(executor.caches.print_caches())
    executor.caches.stats.reset()
executor.finishSimulation()
root.handlers.pop()
logger = logging.getLogger('logger')
while logger.handlers:
    logger.handlers.pop()
cache_info = logging.getLogger('cache_info')
while cache_info.handlers:
    cache_info.handlers.pop()
# Out:
# 2021-05-21 16:27:49,961 - root - INFO - Enable Debugging
# 2021-05-21 16:27:49,963 - root - DEBUG - Mobility disabled
# 2021-05-21 16:27:49,964 - root - DEBUG - Step printing activated
# 2021-05-21 16:27:49,965 - root - DEBUG - Social Graph loaded
# initialized Autonomous System
# 2021-05-21 16:27:49,978 - logger - INFO - initialized Autonomous System
# Start Simulating!
# total seq num:  1000
# Cache in Node(0): ['/content/360', '/content/34', '/content/186', '/content/130', '/content/215', '/content/210', '/content/813', '/content/679', '/content/166', '/content/617']
# Cache in Node(1): ['/content/905', '/content/347', '/content/9', '/content/261', '/content/164', '/content/222', '/content/212', '/content/198', '/content/730', '/content/120']
# Cache in Node(10): ['/content/225', '/content/467', '/content/386', '/content/508', '/content/795', '/content/852', '/content/380', '/content/843', '/content/92', '/content/469']
# Cache in Node(9): ['/content/435', '/content/284', '/content/354', '/content/185', '/content/1', '/content/100', '/content/139', '/content/156', '/content/192', '/content/397']
# Cache in Node(11): ['/content/681', '/content/116', '/content/544', '/content/60', '/content/918', '/content/20', '/content/15', '/content/159', '/content/349', '/content/381']
# Cache in Node(12): ['/content/880', '/content/396', '/content/18', '/content/630', '/content/899', '/content/55', '/content/22', '/content/735', '/content/117', '/content/105']
# Cache in Node(3): ['/content/23', '/content/470', '/content/414', '/content/423', '/content/213', '/content/96', '/content/70', '/content/67', '/content/456', '/content/88']
# Cache in Node(13): ['/content/84', '/content/231', '/content/224', '/content/26', '/content/464', '/content/379', '/content/272', '/content/193', '/content/128', '/content/363']
# Cache in Node(14): ['/content/122', '/content/157', '/content/764', '/content/532', '/content/300', '/content/432', '/content/123', '/content/988', '/content/237', '/content/257']
# Cache in Node(5): ['/content/266', '/content/172', '/content/361', '/content/331', '/content/343', '/content/144', '/content/689', '/content/474', '/content/783', '/content/196']
# Cache in Node(15): ['/content/862', '/content/945', '/content/62', '/content/402', '/content/204', '/content/133', '/content/460', '/content/45', '/content/305']
# Cache in Node(4): ['/content/256', '/content/218', '/content/932', '/content/90', '/content/365', '/content/761', '/content/700', '/content/854', '/content/339', '/content/461']
# Cache in Node(16): ['/content/330', '/content/41', '/content/36', '/content/13', '/content/63', '/content/37', '/content/788', '/content/425', '/content/476', '/content/387']
# Cache in Node(17): ['/content/479', '/content/285', '/content/403', '/content/342', '/content/91', '/content/49', '/content/106', '/content/19', '/content/189', '/content/246']
# Cache in Node(18): ['/content/263', '/content/328', '/content/351', '/content/38', '/content/6', '/content/920', '/content/749', '/content/201', '/content/108', '/content/482']
# Cache in Node(19): ['/content/77', '/content/47', '/content/16', '/content/588', '/content/978', '/content/8', '/content/197', '/content/221', '/content/903', '/content/468']
# Cache in Node(2): ['/content/167', '/content/21', '/content/59', '/content/4', '/content/2', '/content/462', '/content/194', '/content/24', '/content/751', '/content/424']
# Cache in Node(20): ['/content/99', '/content/182', '/content/170', '/content/496', '/content/134', '/content/57', '/content/444', '/content/207', '/content/604', '/content/14']
# Cache in Node(21): ['/content/11', '/content/31', '/content/253', '/content/17', '/content/89', '/content/975', '/content/152', '/content/220', '/content/54', '/content/94']
# Cache in Node(6): ['/content/485', '/content/52', '/content/287', '/content/206', '/content/32', '/content/412', '/content/280', '/content/3', '/content/340', '/content/452']
# Cache in Node(7): ['/content/682', '/content/517', '/content/184', '/content/121', '/content/191', '/content/74', '/content/46', '/content/366', '/content/53', '/content/637']
# Cache in Node(8): ['/content/165', '/content/271', '/content/490', '/content/72', '/content/12', '/content/620', '/content/638', '/content/810', '/content/230', '/content/5']
# Cache in Node(server): []
# Round: 0 , internal_hit: 583 , internal_miss: 417 , stretch : 1024 , cacheHit: 0.0 , stretch: 0.0 hop_reduction: 0.0 get_diversity: 1.0 caching_operations: 417 eviction_operations: 417 Satisfied by caches: 0 _interest: 0, get_rch: 0
# Start Simulating!
# total seq num:  2000
# Cache in Node(0): ['/content/748', '/content/34', '/content/210', '/content/130', '/content/740', '/content/299', '/content/56', '/content/418', '/content/166', '/content/177']
# Cache in Node(1): ['/content/229', '/content/164', '/content/198', '/content/261', '/content/771', '/content/222', '/content/9', '/content/982', '/content/69', '/content/212']
# Cache in Node(10): ['/content/420', '/content/852', '/content/574', '/content/276', '/content/467', '/content/92', '/content/453', '/content/438', '/content/398', '/content/153']
# Cache in Node(9): ['/content/1', '/content/322', '/content/151', '/content/192', '/content/7', '/content/78', '/content/97', '/content/259', '/content/373', '/content/79']
# Cache in Node(11): ['/content/377', '/content/27', '/content/415', '/content/176', '/content/135', '/content/102', '/content/408', '/content/20', '/content/60', '/content/956']
# Cache in Node(12): ['/content/329', '/content/357', '/content/18', '/content/630', '/content/880', '/content/341', '/content/40', '/content/264', '/content/478', '/content/68']
# Cache in Node(3): ['/content/275', '/content/773', '/content/868', '/content/96', '/content/88', '/content/703', '/content/143', '/content/137', '/content/43', '/content/23']
# Cache in Node(13): ['/content/26', '/content/464', '/content/879', '/content/286', '/content/473', '/content/375', '/content/161', '/content/313', '/content/84', '/content/231']
# Cache in Node(14): ['/content/300', '/content/273', '/content/543', '/content/157', '/content/141', '/content/33', '/content/257', '/content/291', '/content/123', '/content/563']
# Cache in Node(5): ['/content/346', '/content/238', '/content/458', '/content/570', '/content/126', '/content/144', '/content/240', '/content/146', '/content/183', '/content/42']
# Cache in Node(15): ['/content/766', '/content/62', '/content/203', '/content/500', '/content/317', '/content/431', '/content/884', '/content/562', '/content/45', '/content/249']
# Cache in Node(4): ['/content/174', '/content/218', '/content/232', '/content/461', '/content/850', '/content/365', '/content/178', '/content/98', '/content/64', '/content/725']
# Cache in Node(16): ['/content/820', '/content/63', '/content/41', '/content/227', '/content/175', '/content/578', '/content/303', '/content/13', '/content/65', '/content/37']
# Cache in Node(17): ['/content/337', '/content/91', '/content/302', '/content/718', '/content/106', '/content/49', '/content/29', '/content/19', '/content/596', '/content/73']
# Cache in Node(18): ['/content/674', '/content/328', '/content/83', '/content/125', '/content/38', '/content/6', '/content/201', '/content/523', '/content/324', '/content/108']
# Cache in Node(19): ['/content/214', '/content/16', '/content/589', '/content/132', '/content/8', '/content/950', '/content/640', '/content/978', '/content/30', '/content/394']
# Cache in Node(2): ['/content/188', '/content/35', '/content/4', '/content/10', '/content/2', '/content/673', '/content/483', '/content/713', '/content/81', '/content/385']
# Cache in Node(20): ['/content/525', '/content/488', '/content/14', '/content/216', '/content/99', '/content/182', '/content/170', '/content/496', '/content/134', '/content/57']
# Cache in Node(21): ['/content/94', '/content/85', '/content/821', '/content/119', '/content/253', '/content/131', '/content/803', '/content/54', '/content/138', '/content/720']
# Cache in Node(6): ['/content/763', '/content/50', '/content/374', '/content/3', '/content/52', '/content/400', '/content/787', '/content/310', '/content/997', '/content/32']
# Cache in Node(7): ['/content/173', '/content/191', '/content/336', '/content/184', '/content/46', '/content/366', '/content/637', '/content/270', '/content/107', '/content/268']
# Cache in Node(8): ['/content/168', '/content/5', '/content/271', '/content/668', '/content/355', '/content/747', '/content/169', '/content/72', '/content/992', '/content/265']
# Cache in Node(server): []
# Round: 1 , internal_hit: 622 , internal_miss: 378 , stretch : 892 , cacheHit: 0.0 , stretch: 0.0 hop_reduction: 0.0 get_diversity: 1.0 caching_operations: 378 eviction_operations: 378 Satisfied by caches: 0 _interest: 0, get_rch: 0
# Start Simulating!
# total seq num:  3000
# Cache in Node(0): ['/content/986', '/content/210', '/content/166', '/content/177', '/content/56', '/content/617', '/content/352', '/content/371', '/content/215', '/content/205']
# Cache in Node(1): ['/content/368', '/content/9', '/content/839', '/content/730', '/content/261', '/content/198', '/content/222', '/content/282', '/content/69', '/content/28']
# Cache in Node(10): ['/content/153', '/content/380', '/content/508', '/content/475', '/content/199', '/content/419', '/content/39', '/content/420', '/content/852', '/content/574']
# Cache in Node(9): ['/content/322', '/content/75', '/content/550', '/content/151', '/content/78', '/content/1', '/content/79', '/content/7', '/content/97', '/content/44']
# Cache in Node(11): ['/content/135', '/content/408', '/content/159', '/content/116', '/content/308', '/content/493', '/content/176', '/content/15', '/content/716', '/content/158']
# Cache in Node(12): ['/content/22', '/content/350', '/content/226', '/content/55', '/content/601', '/content/18', '/content/264', '/content/506', '/content/329', '/content/40']
# Cache in Node(3): ['/content/690', '/content/43', '/content/275', '/content/88', '/content/67', '/content/143', '/content/213', '/content/23', '/content/531', '/content/137']
# Cache in Node(13): ['/content/161', '/content/231', '/content/128', '/content/321', '/content/84', '/content/363', '/content/193', '/content/26', '/content/464', '/content/879']
# Cache in Node(14): ['/content/273', '/content/237', '/content/742', '/content/522', '/content/33', '/content/332', '/content/104', '/content/87', '/content/764', '/content/71']
# Cache in Node(5): ['/content/549', '/content/61', '/content/560', '/content/331', '/content/834', '/content/292', '/content/269', '/content/42', '/content/598', '/content/343']
# Cache in Node(15): ['/content/884', '/content/895', '/content/819', '/content/62', '/content/45', '/content/451', '/content/945', '/content/133', '/content/460', '/content/204']
# Cache in Node(4): ['/content/695', '/content/90', '/content/854', '/content/178', '/content/736', '/content/64', '/content/491', '/content/98', '/content/646', '/content/529']
# Cache in Node(16): ['/content/37', '/content/112', '/content/977', '/content/65', '/content/36', '/content/175', '/content/512', '/content/515', '/content/13', '/content/110']
# Cache in Node(17): ['/content/91', '/content/479', '/content/844', '/content/73', '/content/106', '/content/655', '/content/49', '/content/516', '/content/403', '/content/514']
# Cache in Node(18): ['/content/38', '/content/108', '/content/83', '/content/351', '/content/890', '/content/82', '/content/416', '/content/523', '/content/6', '/content/859']
# Cache in Node(19): ['/content/590', '/content/410', '/content/76', '/content/77', '/content/468', '/content/625', '/content/16', '/content/30', '/content/663', '/content/8']
# Cache in Node(2): ['/content/356', '/content/35', '/content/167', '/content/136', '/content/194', '/content/565', '/content/202', '/content/24', '/content/4', '/content/21']
# Cache in Node(20): ['/content/525', '/content/409', '/content/99', '/content/14', '/content/57', '/content/444', '/content/154', '/content/878', '/content/604', '/content/614']
# Cache in Node(21): ['/content/17', '/content/635', '/content/480', '/content/242', '/content/103', '/content/25', '/content/11', '/content/31', '/content/138', '/content/540']
# Cache in Node(6): ['/content/340', '/content/615', '/content/32', '/content/50', '/content/521', '/content/599', '/content/155', '/content/3', '/content/52', '/content/882']
# Cache in Node(7): ['/content/184', '/content/962', '/content/691', '/content/289', '/content/505', '/content/46', '/content/535', '/content/74', '/content/277', '/content/53']
# Cache in Node(8): ['/content/311', '/content/72', '/content/12', '/content/230', '/content/5', '/content/281', '/content/355', '/content/58', '/content/169', '/content/304']
# Cache in Node(server): []
# Round: 2 , internal_hit: 620 , internal_miss: 380 , stretch : 893 , cacheHit: 0.0 , stretch: 0.0 hop_reduction: 0.0 get_diversity: 1.0 caching_operations: 380 eviction_operations: 380 Satisfied by caches: 0 _interest: 0, get_rch: 0
# Start Simulating!
# total seq num:  4000
# Cache in Node(0): ['/content/205', '/content/418', '/content/665', '/content/56', '/content/617', '/content/299', '/content/371', '/content/34', '/content/215', '/content/130']
# Cache in Node(1): ['/content/229', '/content/28', '/content/347', '/content/752', '/content/318', '/content/282', '/content/9', '/content/845', '/content/160', '/content/212']
# Cache in Node(10): ['/content/438', '/content/92', '/content/475', '/content/467', '/content/181', '/content/866', '/content/39', '/content/326', '/content/940', '/content/823']
# Cache in Node(9): ['/content/75', '/content/7', '/content/1', '/content/79', '/content/322', '/content/100', '/content/472', '/content/93', '/content/78', '/content/373']
# Cache in Node(11): ['/content/27', '/content/15', '/content/159', '/content/876', '/content/681', '/content/60', '/content/308', '/content/109', '/content/716', '/content/171']
# Cache in Node(12): ['/content/118', '/content/899', '/content/18', '/content/105', '/content/68', '/content/22', '/content/886', '/content/396', '/content/610', '/content/235']
# Cache in Node(3): ['/content/143', '/content/67', '/content/43', '/content/275', '/content/423', '/content/414', '/content/96', '/content/904', '/content/137', '/content/23']
# Cache in Node(13): ['/content/894', '/content/26', '/content/272', '/content/879', '/content/286', '/content/288', '/content/161', '/content/231', '/content/128', '/content/321']
# Cache in Node(14): ['/content/71', '/content/742', '/content/555', '/content/157', '/content/104', '/content/123', '/content/332', '/content/257', '/content/999', '/content/636']
# Cache in Node(5): ['/content/172', '/content/808', '/content/343', '/content/598', '/content/144', '/content/266', '/content/570', '/content/42', '/content/579', '/content/51']
# Cache in Node(15): ['/content/249', '/content/133', '/content/861', '/content/597', '/content/774', '/content/393', '/content/402', '/content/862', '/content/204', '/content/791']
# Cache in Node(4): ['/content/90', '/content/327', '/content/256', '/content/174', '/content/339', '/content/64', '/content/232', '/content/683', '/content/725', '/content/818']
# Cache in Node(16): ['/content/36', '/content/593', '/content/112', '/content/678', '/content/518', '/content/626', '/content/41', '/content/446', '/content/37', '/content/13']
# Cache in Node(17): ['/content/29', '/content/91', '/content/219', '/content/296', '/content/302', '/content/106', '/content/492', '/content/403', '/content/73', '/content/49']
# Cache in Node(18): ['/content/83', '/content/6', '/content/704', '/content/482', '/content/898', '/content/124', '/content/351', '/content/108', '/content/82', '/content/201']
# Cache in Node(19): ['/content/208', '/content/933', '/content/142', '/content/76', '/content/602', '/content/16', '/content/537', '/content/197', '/content/675', '/content/8']
# Cache in Node(2): ['/content/81', '/content/10', '/content/59', '/content/4', '/content/234', '/content/167', '/content/202', '/content/2', '/content/483', '/content/35']
# Cache in Node(20): ['/content/488', '/content/134', '/content/672', '/content/938', '/content/496', '/content/525', '/content/409', '/content/99', '/content/14', '/content/57']
# Cache in Node(21): ['/content/720', '/content/11', '/content/85', '/content/54', '/content/89', '/content/709', '/content/17', '/content/220', '/content/242', '/content/66']
# Cache in Node(6): ['/content/52', '/content/641', '/content/452', '/content/585', '/content/280', '/content/50', '/content/228', '/content/287', '/content/374', '/content/3']
# Cache in Node(7): ['/content/404', '/content/336', '/content/722', '/content/268', '/content/191', '/content/95', '/content/991', '/content/121', '/content/270', '/content/362']
# Cache in Node(8): ['/content/168', '/content/72', '/content/964', '/content/12', '/content/5', '/content/58', '/content/294', '/content/797', '/content/389', '/content/298']
# Cache in Node(server): []
# Round: 3 , internal_hit: 641 , internal_miss: 359 , stretch : 848 , cacheHit: 0.0 , stretch: 0.0 hop_reduction: 0.0 get_diversity: 1.0 caching_operations: 359 eviction_operations: 359 Satisfied by caches: 0 _interest: 0, get_rch: 0
# Start Simulating!
# total seq num:  5000
# Cache in Node(0): ['/content/56', '/content/215', '/content/299', '/content/813', '/content/825', '/content/679', '/content/177', '/content/34', '/content/741', '/content/210']
# Cache in Node(1): ['/content/120', '/content/258', '/content/9', '/content/368', '/content/212', '/content/405', '/content/69', '/content/229', '/content/28', '/content/347']
# Cache in Node(10): ['/content/386', '/content/508', '/content/225', '/content/659', '/content/398', '/content/867', '/content/153', '/content/438', '/content/92', '/content/475']
# Cache in Node(9): ['/content/150', '/content/567', '/content/7', '/content/1', '/content/129', '/content/78', '/content/127', '/content/511', '/content/75', '/content/44']
# Cache in Node(11): ['/content/359', '/content/241', '/content/676', '/content/840', '/content/15', '/content/581', '/content/415', '/content/267', '/content/767', '/content/135']
# Cache in Node(12): ['/content/857', '/content/341', '/content/907', '/content/68', '/content/55', '/content/18', '/content/235', '/content/105', '/content/329', '/content/22']
# Cache in Node(3): ['/content/732', '/content/690', '/content/531', '/content/233', '/content/23', '/content/70', '/content/456', '/content/143', '/content/67', '/content/43']
# Cache in Node(13): ['/content/892', '/content/231', '/content/786', '/content/84', '/content/128', '/content/466', '/content/348', '/content/894', '/content/26', '/content/272']
# Cache in Node(14): ['/content/104', '/content/71', '/content/33', '/content/248', '/content/532', '/content/919', '/content/122', '/content/141', '/content/157', '/content/291']
# Cache in Node(5): ['/content/196', '/content/331', '/content/42', '/content/309', '/content/692', '/content/783', '/content/51', '/content/269', '/content/183', '/content/777']
# Cache in Node(15): ['/content/297', '/content/963', '/content/393', '/content/647', '/content/45', '/content/305', '/content/62', '/content/203', '/content/249', '/content/133']
# Cache in Node(4): ['/content/178', '/content/842', '/content/646', '/content/849', '/content/64', '/content/239', '/content/98', '/content/232', '/content/491', '/content/295']
# Cache in Node(16): ['/content/858', '/content/13', '/content/251', '/content/112', '/content/65', '/content/593', '/content/110', '/content/443', '/content/163', '/content/512']
# Cache in Node(17): ['/content/29', '/content/91', '/content/799', '/content/337', '/content/302', '/content/189', '/content/19', '/content/49', '/content/902', '/content/148']
# Cache in Node(18): ['/content/806', '/content/6', '/content/260', '/content/674', '/content/82', '/content/201', '/content/38', '/content/727', '/content/573', '/content/804']
# Cache in Node(19): ['/content/922', '/content/142', '/content/197', '/content/660', '/content/16', '/content/812', '/content/8', '/content/47', '/content/757', '/content/30']
# Cache in Node(2): ['/content/59', '/content/702', '/content/816', '/content/167', '/content/10', '/content/4', '/content/21', '/content/872', '/content/81', '/content/860']
# Cache in Node(20): ['/content/935', '/content/496', '/content/525', '/content/57', '/content/99', '/content/14', '/content/216', '/content/444', '/content/488', '/content/134']
# Cache in Node(21): ['/content/94', '/content/66', '/content/220', '/content/25', '/content/803', '/content/31', '/content/119', '/content/720', '/content/11', '/content/242']
# Cache in Node(6): ['/content/586', '/content/3', '/content/648', '/content/228', '/content/521', '/content/340', '/content/52', '/content/485', '/content/395', '/content/656']
# Cache in Node(7): ['/content/95', '/content/691', '/content/53', '/content/107', '/content/74', '/content/121', '/content/637', '/content/552', '/content/173', '/content/497']
# Cache in Node(8): ['/content/835', '/content/58', '/content/271', '/content/504', '/content/72', '/content/992', '/content/298', '/content/12', '/content/5', '/content/165']
# Cache in Node(server): []
# Round: 4 , internal_hit: 659 , internal_miss: 341 , stretch : 830 , cacheHit: 0.0 , stretch: 0.0 hop_reduction: 0.0 get_diversity: 1.0 caching_operations: 341 eviction_operations: 341 Satisfied by caches: 0 _interest: 0, get_rch: 0

# %%
mainFunc(options)
# Out:
# 2021-05-21 16:30:30,154 - root - INFO - Enable Debugging
# 2021-05-21 16:30:30,154 - root - DEBUG - Mobility disabled
# 2021-05-21 16:30:30,155 - root - DEBUG - Step printing activated
# 2021-05-21 16:30:30,155 - root - DEBUG - Social Graph loaded
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-25-3f254929f3d1> in <module>
# ----> 1 mainFunc(options)
#
# <ipython-input-19-070685159397> in mainFunc(options)
#      55         #plotGraph(petersen)
#      56         # social_graph, topology, cache_size, caching_strategy, cache_policy, sequence_filename, mobility_enabled, step_printing, topology_file
# ---> 57         executor = Executor(logger,G, petersen, CACHE_SIZE, CACHING_STRATEGY, CACHE_STRUCTURE, SEQUENCE_FILE, MOBILITY_ENABLED, STEP_PRINTING, topology_file=TOPOLOGY_GRAPH, zipf = ZIPF, method = METHOD, single = SINGLE, verbose = VERBOSE)
#      58         executor.run()
#      59         print(executor.printStats())
#
# UnboundLocalError: local variable 'logger' referenced before assignment

# %% [markdown]
# ## 5 Visualization

# %%
#TOPOLOGY_GRAPH = options.network_topology
#G = getattr(__import__('graphs.%s'%TOPOLOGY_GRAPH), TOPOLOGY_GRAPH).G
G = executor.topology
topo_vis = vis(G, executor.topology_coords)
node = random.choice(list(G.nodes()))
G.add_node("server", label = "server")
G.add_edge(node,"server")

# %%
AS1 = AS(list(G.nodes()),True)
print(AS1.get_nodes())
AS1.get_node("coconut")
# Out:
# [0, 1, 10, 9, 11, 12, 3, 13, 14, 5, 15, 4, 16, 17, 18, 19, 2, 20, 21, 6, 7, 8]
# 15

# %%
        pos = executor.topology_coords
        Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
        fig = plt.figure(figsize=(10, 10))
        ax0 = fig.subplots()
        nx.draw_networkx_nodes(G, pos,  node_size = 80)
        nx.draw_networkx_edges(G,pos, alpha = 0.6)
        pos1 = {}
        for p in pos:  # raise text positions
            #pos[p] = [p[0]+0.05, p[1]+0.04]
            pos1[p] = pos[p][0]+0.005,pos[p][1]+0.003
        plt.title('label graph')
        nx.draw_networkx_labels(G, pos1,  font_size = 20)
        plt.show()
        #print(pos, pos1)

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, font_size=16)
for p in pos:  # raise text positions
    pos[p][0] += 0.05
    pos[p][1] += 0.09
nx.draw_networkx_labels(G, pos)
plt.show()

# %%
topo_vis.label_graph(font_size = 1, node_size = 210)

# %% [markdown]
# # 节点的介度

# %%
print("Betweenness")
b = nx.betweenness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, b[v]))

print("Degree centrality")
d = nx.degree_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, d[v]))

print("Closeness centrality")
c = nx.closeness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, c[v]))

nx.draw(G, pos, font_size=16)
for p in pos:  # raise text positions
    pos[p][0] += 0.05
    pos[p][1] += 0.09
nx.draw_networkx_labels(G, pos)
plt.show()
# Out:
# Betweenness
# 00 0.011
# 01 0.083
# 10 0.006
# 09 0.087
# 11 0.037
# 12 0.260
# 03 0.164
# 13 0.033
# 14 0.191
# 05 0.070
# 15 0.158
# 04 0.199
# 16 0.005
# 17 0.067
# 18 0.150
# 19 0.000
# 02 0.000
# 20 0.013
# 21 0.088
# 06 0.014
# 07 0.094
# 08 0.032
# Degree centrality
# 00 0.095
# 01 0.238
# 10 0.095
# 09 0.143
# 11 0.095
# 12 0.238
# 03 0.238
# 13 0.095
# 14 0.286
# 05 0.143
# 15 0.238
# 04 0.238
# 16 0.095
# 17 0.190
# 18 0.238
# 19 0.095
# 02 0.095
# 20 0.143
# 21 0.190
# 06 0.095
# 07 0.143
# 08 0.095
# Closeness centrality
# 00 0.362
# 01 0.438
# 10 0.269
# 09 0.350
# 11 0.323
# 12 0.447
# 03 0.500
# 13 0.404
# 14 0.477
# 05 0.438
# 15 0.500
# 04 0.488
# 16 0.350
# 17 0.420
# 18 0.429
# 19 0.318
# 02 0.368
# 20 0.328
# 21 0.420
# 06 0.344
# 07 0.389
# 08 0.328

# %%
print(sum(d.values()))
# Out:
# 3.523809523809524

# %%
print(44/21)
# Out:
# 2.0952380952380953

# %%
SOCIAL_GRAPH = options.social_graph
G = getattr(__import__('graphs.%s'%SOCIAL_GRAPH), SOCIAL_GRAPH).G
social_vis = vis(G)

# %%
social_vis.degree_graph()

# %%
social_vis.simple_graph(node_size = 10, alpha = 0.2, size = 12)

# %%
print("Betweenness")
b = nx.betweenness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, b[v]))

print("Degree centrality")
d = nx.degree_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, d[v]))

print("Closeness centrality")
c = nx.closeness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, c[v]))

pos = nx.spring_layout(G)
nx.draw(G, pos, font_size=16)
for p in pos:  # raise text positions
    pos[p][0] += 0.05
    pos[p][1] += 0.09
nx.draw_networkx_labels(G, pos)
plt.show()
# Out:
# Betweenness
# 00 0.011
# 01 0.083
# 10 0.006
# 09 0.087
# 11 0.037
# 12 0.260
# 03 0.164
# 13 0.033
# 14 0.191
# 05 0.070
# 15 0.158
# 04 0.199
# 16 0.005
# 17 0.067
# 18 0.150
# 19 0.000
# 02 0.000
# 20 0.013
# 21 0.088
# 06 0.014
# 07 0.094
# 08 0.032
# Degree centrality
# 00 0.095
# 01 0.238
# 10 0.095
# 09 0.143
# 11 0.095
# 12 0.238
# 03 0.238
# 13 0.095
# 14 0.286
# 05 0.143
# 15 0.238
# 04 0.238
# 16 0.095
# 17 0.190
# 18 0.238
# 19 0.095
# 02 0.095
# 20 0.143
# 21 0.190
# 06 0.095
# 07 0.143
# 08 0.095
# Closeness centrality
# 00 0.362
# 01 0.438
# 10 0.269
# 09 0.350
# 11 0.323
# 12 0.447
# 03 0.500
# 13 0.404
# 14 0.477
# 05 0.438
# 15 0.500
# 04 0.488
# 16 0.350
# 17 0.420
# 18 0.429
# 19 0.318
# 02 0.368
# 20 0.328
# 21 0.420
# 06 0.344
# 07 0.389
# 08 0.328

# %%
topo_vis.directed_graph()
# Out:
# /Users/sijiazhang/jupyter_notebook/socialccnsim/visualize.py:35: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   plt.colorbar(pc)

# %%
topo_vis.degree_graph()

# %%
topo_vis.simple_graph()

# %%
args = '-c 2 -s lce -u facebook -t geant -p lru -f exampletrace/verysmall -d True'
(options,args) = parser.parse_args(args.split(' '))

# %%
TOPOLOGY_GRAPH = options.network_topology
G = getattr(__import__('graphs.%s'%TOPOLOGY_GRAPH), TOPOLOGY_GRAPH).G
topo_vis = vis(G)

# %%
topo_vis.degree_graph()

# %%
G = nx.Graph()  # or DiGraph, MultiGraph, MultiDiGraph, etc
G.add_nodes_from("Hello")
K3 = nx.Graph([(0, 1), (1, 2), (2, 0)])
G.add_nodes_from(K3)

# %%
viser = vis(G)
viser.directed_graph()

# %%
viser.degree_graph()
